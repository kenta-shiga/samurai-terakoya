# %%
user_names =["月曜日は晴れです",
             "火曜日は雨です",
             "水曜日は晴れです",
             "木曜日は晴れです",
             "金曜日は曇りです",
             "土曜日は曇りのち雨です",
             "日曜日は雷雨です"]

#水曜日の天気だけ取り出す

print(user_names[2])
# Out:
# 水曜日は晴れです

# %%
weather_name = {"mon":"晴れ","tue":"雨","wed":"晴れ","thu":"晴れ","fri":"曇り","sat":"曇りのち雨","sun":"雷雨"}

#水曜日の天気だけ取り出す

print(weather_name["wed"])
# Out:
# 晴れ

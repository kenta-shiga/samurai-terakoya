# %%
class User:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def set_name(self,name):
      self.name = name

    def show_name(self):
     print(self.name)

user = User("侍太郎", 36)

print(user.name)
print(user.age)
# Out:
# 侍太郎
# 36

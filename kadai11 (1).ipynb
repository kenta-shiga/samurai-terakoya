# %%
user_names = ["水","金","地","火","木","土","天","海","冥"]

for user_name in user_names:
  print(user_name)


user_names = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]
count = 0

while count < 1:
    for user_name in user_names:
      print(user_name)
    count += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
#上辺 = 10cm
#下辺 = 20cm
#高さ = 5cm

#公式：台数の面積 = （上辺 + 下辺）× 高さ ÷ 2

number1 = 10
number2 = 20
number3 = 5
X = (number1 + number2) * number3 / 2
print(str(X)+" ㎠")
# Out:
# 75.0 ㎠

# %% [markdown]
# # 新しいセクション
